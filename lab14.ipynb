# %% [markdown]
# <a href="https://colab.research.google.com/github/tammyhanberg/Bio-125/blob/main/lab14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import packages
import statistics
import pandas as pd
import scipy.stats as stats
from scipy.stats import sem
from statistics import mean, stdev
import matplotlib.pyplot as plt
import numpy as np
#include if using a jupyter notebook, remove if using a .py file
# %matplotlib inline

# %%
f_vc=[2.7,3.7,3.2,3.45,3.2,3.1]
m_vc=[3.3,4.5,3.7]
f_vc, m_vc
# Out:
# ([2.7, 3.7, 3.2, 3.45, 3.2, 3.1], [3.3, 4.5, 3.7])

# %%
fvc_sem = sem(f_vc)
mvc_sem = sem(m_vc)
fvc_sem, mvc_sem
# Out:
# (0.13768926368215256, 0.3527668414752788)

# %%
plt.bar(['Female VC', 'Male VC'], [fvc_mean,mvc_mean], yerr=[fvc_sem, mvc_sem], capsize=10)
plt.xlabel('Biological Sex')
plt.ylabel('Vital Capacity (L)')
plt.title('Vital Capacity Differences In Male vs Female')
# Out:
# Text(0.5, 1.0, 'Vital Capacity Differences In Male vs Female')

# %%
from google.colab import drive
drive.mount('/content/drive')
